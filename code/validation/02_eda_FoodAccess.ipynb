# %% [markdown]
# # EDA Food Access Dataset
#
# # Introduction
#
# This dataset contains information about food access in various regions. It includes data on grocery stores, food deserts, and demographic information related to food accessibility. The goal of this exploratory data analysis (EDA) is to understand the distribution of food access across different areas and identify potential disparities.

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# %% [markdown]
# # Read The excel file

# %%
base_path = Path.cwd().parents[1]  # Get the parent directory of the current working directory

data_path = base_path / "data" / "raw"/ "FoodAccessResearchAtlasData2019.xlsx"

df = pd.read_excel(data_path)

print(f"Data loaded successfully")
# Out:
# Data loaded successfully
